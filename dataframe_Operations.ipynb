# %% [markdown]
# ## Dataframe Operations transformation & Actions

# %% [markdown]
# # Initializing Spark

# %%
import findspark
findspark.init()
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Data frame Operations").getOrCreate()
sc = spark.sparkContext

# %%
df_csv = spark.read.csv("Automobile_data.csv", header=True, inferSchema=True)
df_csv.show()
# Out:
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |symboling|normalized-losses|       make|fuel-type|aspiration|num-of-doors| body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|price|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|13495|
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|16500|
# |        1|                ?|alfa-romero|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 171.2| 65.5|  52.4|       2823|       ohcv|             six|        152|       mpfi|2.68|  3.47|              9.0|       154|    5000|      19|         26|16500|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         4wd|          front|      99.4| 176.6| 66.4|  54.3|       2824|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.0|       115|    5500|      18|         22|17450|
# |        2|                ?|       audi|      gas|       std|         two|      sedan|         fwd|          front|      99.8| 177.3| 66.3|  53.1|       2507|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|15250|
# |        1|              158|       audi|      gas|       std|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2844|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|17710|
# |        1|                ?|       audi|      gas|       std|        four|      wagon|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2954|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|18920|
# |        1|              158|       audi|      gas|     turbo|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.9|       3086|        ohc|            five|        131|       mpfi|3.13|   3.4|              8.3|       140|    5500|      17|         20|23875|
# |        0|                ?|       audi|      gas|     turbo|         two|  hatchback|         4wd|          front|      99.5| 178.2| 67.9|  52.0|       3053|        ohc|            five|        131|       mpfi|3.13|   3.4|              7.0|       160|    5500|      16|         22|    ?|
# |        2|              192|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|16430|
# |        0|              192|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|16925|
# |        0|              188|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2710|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|20970|
# |        0|              188|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2765|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|21105|
# |        1|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3055|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      20|         25|24565|
# |        0|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3230|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|30760|
# |        0|                ?|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     103.5| 193.8| 67.9|  53.7|       3380|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|41315|
# |        0|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     110.0| 197.0| 70.9|  56.3|       3505|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      15|         20|36880|
# |        2|              121|  chevrolet|      gas|       std|         two|  hatchback|         fwd|          front|      88.4| 141.1| 60.3|  53.2|       1488|          l|           three|         61|       2bbl|2.91|  3.03|              9.5|        48|    5100|      47|         53| 5151|
# |        1|               98|  chevrolet|      gas|       std|         two|  hatchback|         fwd|          front|      94.5| 155.9| 63.6|  52.0|       1874|        ohc|            four|         90|       2bbl|3.03|  3.11|              9.6|        70|    5400|      38|         43| 6295|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# only showing top 20 rows

# %% [markdown]
# # 🔵 1. select()
#
# Choose specific columns.

# %%
df_csv.select("make","num-of-doors", "horsepower","price",).show()
# Out:
# +-----------+------------+----------+-----+
# |       make|num-of-doors|horsepower|price|
# +-----------+------------+----------+-----+
# |alfa-romero|         two|       111|13495|
# |alfa-romero|         two|       111|16500|
# |alfa-romero|         two|       154|16500|
# |       audi|        four|       102|13950|
# |       audi|        four|       115|17450|
# |       audi|         two|       110|15250|
# |       audi|        four|       110|17710|
# |       audi|        four|       110|18920|
# |       audi|        four|       140|23875|
# |       audi|         two|       160|    ?|
# |        bmw|         two|       101|16430|
# |        bmw|        four|       101|16925|
# |        bmw|         two|       121|20970|
# |        bmw|        four|       121|21105|
# |        bmw|        four|       121|24565|
# |        bmw|        four|       182|30760|
# |        bmw|         two|       182|41315|
# |        bmw|        four|       182|36880|
# |  chevrolet|         two|        48| 5151|
# |  chevrolet|         two|        70| 6295|
# +-----------+------------+----------+-----+
# only showing top 20 rows

# %% [markdown]
# 🔵 2. selectExpr()
#
# SQL expressions inside select.

# %%
#"make","num-of-doors", "horsepower","price",
df_csv.selectExpr("make","price", "price * 1.1 as new_price").show()
# Out:
# +-----------+-----+------------------+
# |       make|price|         new_price|
# +-----------+-----+------------------+
# |alfa-romero|13495|14844.500000000002|
# |alfa-romero|16500|           18150.0|
# |alfa-romero|16500|           18150.0|
# |       audi|13950|15345.000000000002|
# |       audi|17450|           19195.0|
# |       audi|15250|           16775.0|
# |       audi|17710|           19481.0|
# |       audi|18920|           20812.0|
# |       audi|23875|26262.500000000004|
# |       audi|    ?|              NULL|
# |        bmw|16430|           18073.0|
# |        bmw|16925|           18617.5|
# |        bmw|20970|23067.000000000004|
# |        bmw|21105|23215.500000000004|
# |        bmw|24565|27021.500000000004|
# |        bmw|30760|           33836.0|
# |        bmw|41315| 45446.50000000001|
# |        bmw|36880|           40568.0|
# |  chevrolet| 5151|            5666.1|
# |  chevrolet| 6295| 6924.500000000001|
# +-----------+-----+------------------+
# only showing top 20 rows

# %% [markdown]
# 🔵 3. filter() / where()
#
# Filter rows based on a condition.

# %%
df_csv.filter(df_csv.price > 25000).show()
# Out:
# +---------+-----------------+-------------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |symboling|normalized-losses|         make|fuel-type|aspiration|num-of-doors| body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|price|
# +---------+-----------------+-------------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |        0|                ?|          bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3230|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|30760|
# |        0|                ?|          bmw|      gas|       std|         two|      sedan|         rwd|          front|     103.5| 193.8| 67.9|  53.7|       3380|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|41315|
# |        0|                ?|          bmw|      gas|       std|        four|      sedan|         rwd|          front|     110.0| 197.0| 70.9|  56.3|       3505|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      15|         20|36880|
# |        0|              145|       jaguar|      gas|       std|        four|      sedan|         rwd|          front|     113.0| 199.6| 69.6|  52.8|       4066|       dohc|             six|        258|       mpfi|3.63|  4.17|              8.1|       176|    4750|      15|         19|32250|
# |        0|                ?|       jaguar|      gas|       std|        four|      sedan|         rwd|          front|     113.0| 199.6| 69.6|  52.8|       4066|       dohc|             six|        258|       mpfi|3.63|  4.17|              8.1|       176|    4750|      15|         19|35550|
# |        0|                ?|       jaguar|      gas|       std|         two|      sedan|         rwd|          front|     102.0| 191.7| 70.6|  47.8|       3950|       ohcv|          twelve|        326|       mpfi|3.54|  2.76|             11.5|       262|    5000|      13|         17|36000|
# |       -1|               93|mercedes-benz|   diesel|     turbo|        four|      sedan|         rwd|          front|     110.0| 190.9| 70.3|  56.5|       3515|        ohc|            five|        183|        idi|3.58|  3.64|             21.5|       123|    4350|      22|         25|25552|
# |       -1|               93|mercedes-benz|   diesel|     turbo|        four|      wagon|         rwd|          front|     110.0| 190.9| 70.3|  58.7|       3750|        ohc|            five|        183|        idi|3.58|  3.64|             21.5|       123|    4350|      22|         25|28248|
# |        0|               93|mercedes-benz|   diesel|     turbo|         two|    hardtop|         rwd|          front|     106.7| 187.5| 70.3|  54.9|       3495|        ohc|            five|        183|        idi|3.58|  3.64|             21.5|       123|    4350|      22|         25|28176|
# |       -1|               93|mercedes-benz|   diesel|     turbo|        four|      sedan|         rwd|          front|     115.6| 202.6| 71.7|  56.3|       3770|        ohc|            five|        183|        idi|3.58|  3.64|             21.5|       123|    4350|      22|         25|31600|
# |       -1|                ?|mercedes-benz|      gas|       std|        four|      sedan|         rwd|          front|     115.6| 202.6| 71.7|  56.5|       3740|       ohcv|           eight|        234|       mpfi|3.46|   3.1|              8.3|       155|    4750|      16|         18|34184|
# |        3|              142|mercedes-benz|      gas|       std|         two|convertible|         rwd|          front|      96.6| 180.3| 70.5|  50.8|       3685|       ohcv|           eight|        234|       mpfi|3.46|   3.1|              8.3|       155|    4750|      16|         18|35056|
# |        0|                ?|mercedes-benz|      gas|       std|        four|      sedan|         rwd|          front|     120.9| 208.1| 71.7|  56.7|       3900|       ohcv|           eight|        308|       mpfi| 3.8|  3.35|              8.0|       184|    4500|      14|         16|40960|
# |        1|                ?|mercedes-benz|      gas|       std|         two|    hardtop|         rwd|          front|     112.0| 199.2| 72.0|  55.4|       3715|       ohcv|           eight|        304|       mpfi| 3.8|  3.35|              8.0|       184|    4500|      14|         16|45400|
# |        3|                ?|      porsche|      gas|       std|         two|    hardtop|         rwd|           rear|      89.5| 168.9| 65.0|  51.6|       2756|       ohcf|             six|        194|       mpfi|3.74|   2.9|              9.5|       207|    5900|      17|         25|32528|
# |        3|                ?|      porsche|      gas|       std|         two|    hardtop|         rwd|           rear|      89.5| 168.9| 65.0|  51.6|       2756|       ohcf|             six|        194|       mpfi|3.74|   2.9|              9.5|       207|    5900|      17|         25|34028|
# |        3|                ?|      porsche|      gas|       std|         two|convertible|         rwd|           rear|      89.5| 168.9| 65.0|  51.6|       2800|       ohcf|             six|        194|       mpfi|3.74|   2.9|              9.5|       207|    5900|      17|         25|37028|
# +---------+-----------------+-------------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+

# %%
df_csv.where("price > 25000").show()
# Out:
# +---------+-----------------+-------------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |symboling|normalized-losses|         make|fuel-type|aspiration|num-of-doors| body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|price|
# +---------+-----------------+-------------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |        0|                ?|          bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3230|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|30760|
# |        0|                ?|          bmw|      gas|       std|         two|      sedan|         rwd|          front|     103.5| 193.8| 67.9|  53.7|       3380|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|41315|
# |        0|                ?|          bmw|      gas|       std|        four|      sedan|         rwd|          front|     110.0| 197.0| 70.9|  56.3|       3505|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      15|         20|36880|
# |        0|              145|       jaguar|      gas|       std|        four|      sedan|         rwd|          front|     113.0| 199.6| 69.6|  52.8|       4066|       dohc|             six|        258|       mpfi|3.63|  4.17|              8.1|       176|    4750|      15|         19|32250|
# |        0|                ?|       jaguar|      gas|       std|        four|      sedan|         rwd|          front|     113.0| 199.6| 69.6|  52.8|       4066|       dohc|             six|        258|       mpfi|3.63|  4.17|              8.1|       176|    4750|      15|         19|35550|
# |        0|                ?|       jaguar|      gas|       std|         two|      sedan|         rwd|          front|     102.0| 191.7| 70.6|  47.8|       3950|       ohcv|          twelve|        326|       mpfi|3.54|  2.76|             11.5|       262|    5000|      13|         17|36000|
# |       -1|               93|mercedes-benz|   diesel|     turbo|        four|      sedan|         rwd|          front|     110.0| 190.9| 70.3|  56.5|       3515|        ohc|            five|        183|        idi|3.58|  3.64|             21.5|       123|    4350|      22|         25|25552|
# |       -1|               93|mercedes-benz|   diesel|     turbo|        four|      wagon|         rwd|          front|     110.0| 190.9| 70.3|  58.7|       3750|        ohc|            five|        183|        idi|3.58|  3.64|             21.5|       123|    4350|      22|         25|28248|
# |        0|               93|mercedes-benz|   diesel|     turbo|         two|    hardtop|         rwd|          front|     106.7| 187.5| 70.3|  54.9|       3495|        ohc|            five|        183|        idi|3.58|  3.64|             21.5|       123|    4350|      22|         25|28176|
# |       -1|               93|mercedes-benz|   diesel|     turbo|        four|      sedan|         rwd|          front|     115.6| 202.6| 71.7|  56.3|       3770|        ohc|            five|        183|        idi|3.58|  3.64|             21.5|       123|    4350|      22|         25|31600|
# |       -1|                ?|mercedes-benz|      gas|       std|        four|      sedan|         rwd|          front|     115.6| 202.6| 71.7|  56.5|       3740|       ohcv|           eight|        234|       mpfi|3.46|   3.1|              8.3|       155|    4750|      16|         18|34184|
# |        3|              142|mercedes-benz|      gas|       std|         two|convertible|         rwd|          front|      96.6| 180.3| 70.5|  50.8|       3685|       ohcv|           eight|        234|       mpfi|3.46|   3.1|              8.3|       155|    4750|      16|         18|35056|
# |        0|                ?|mercedes-benz|      gas|       std|        four|      sedan|         rwd|          front|     120.9| 208.1| 71.7|  56.7|       3900|       ohcv|           eight|        308|       mpfi| 3.8|  3.35|              8.0|       184|    4500|      14|         16|40960|
# |        1|                ?|mercedes-benz|      gas|       std|         two|    hardtop|         rwd|          front|     112.0| 199.2| 72.0|  55.4|       3715|       ohcv|           eight|        304|       mpfi| 3.8|  3.35|              8.0|       184|    4500|      14|         16|45400|
# |        3|                ?|      porsche|      gas|       std|         two|    hardtop|         rwd|           rear|      89.5| 168.9| 65.0|  51.6|       2756|       ohcf|             six|        194|       mpfi|3.74|   2.9|              9.5|       207|    5900|      17|         25|32528|
# |        3|                ?|      porsche|      gas|       std|         two|    hardtop|         rwd|           rear|      89.5| 168.9| 65.0|  51.6|       2756|       ohcf|             six|        194|       mpfi|3.74|   2.9|              9.5|       207|    5900|      17|         25|34028|
# |        3|                ?|      porsche|      gas|       std|         two|convertible|         rwd|           rear|      89.5| 168.9| 65.0|  51.6|       2800|       ohcf|             six|        194|       mpfi|3.74|   2.9|              9.5|       207|    5900|      17|         25|37028|
# +---------+-----------------+-------------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+

# %% [markdown]
# 🔵 4. withColumn()
#
# Add or replace a column.

# %%
df2 = df_csv.withColumn("GST", df_csv.price * 0.12)
df2.show()
# Out:
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+------------------+
# |symboling|normalized-losses|       make|fuel-type|aspiration|num-of-doors| body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|price|               GST|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+------------------+
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|13495|1619.3999999999999|
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|16500|            1980.0|
# |        1|                ?|alfa-romero|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 171.2| 65.5|  52.4|       2823|       ohcv|             six|        152|       mpfi|2.68|  3.47|              9.0|       154|    5000|      19|         26|16500|            1980.0|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|            1674.0|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         4wd|          front|      99.4| 176.6| 66.4|  54.3|       2824|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.0|       115|    5500|      18|         22|17450|            2094.0|
# |        2|                ?|       audi|      gas|       std|         two|      sedan|         fwd|          front|      99.8| 177.3| 66.3|  53.1|       2507|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|15250|            1830.0|
# |        1|              158|       audi|      gas|       std|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2844|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|17710|            2125.2|
# |        1|                ?|       audi|      gas|       std|        four|      wagon|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2954|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|18920|            2270.4|
# |        1|              158|       audi|      gas|     turbo|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.9|       3086|        ohc|            five|        131|       mpfi|3.13|   3.4|              8.3|       140|    5500|      17|         20|23875|            2865.0|
# |        0|                ?|       audi|      gas|     turbo|         two|  hatchback|         4wd|          front|      99.5| 178.2| 67.9|  52.0|       3053|        ohc|            five|        131|       mpfi|3.13|   3.4|              7.0|       160|    5500|      16|         22|    ?|              NULL|
# |        2|              192|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|16430|            1971.6|
# |        0|              192|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|16925|            2031.0|
# |        0|              188|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2710|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|20970|            2516.4|
# |        0|              188|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2765|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|21105|            2532.6|
# |        1|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3055|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      20|         25|24565|2947.7999999999997|
# |        0|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3230|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|30760|            3691.2|
# |        0|                ?|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     103.5| 193.8| 67.9|  53.7|       3380|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|41315|            4957.8|
# |        0|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     110.0| 197.0| 70.9|  56.3|       3505|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      15|         20|36880| 4425.599999999999|
# |        2|              121|  chevrolet|      gas|       std|         two|  hatchback|         fwd|          front|      88.4| 141.1| 60.3|  53.2|       1488|          l|           three|         61|       2bbl|2.91|  3.03|              9.5|        48|    5100|      47|         53| 5151|            618.12|
# |        1|               98|  chevrolet|      gas|       std|         two|  hatchback|         fwd|          front|      94.5| 155.9| 63.6|  52.0|       1874|        ohc|            four|         90|       2bbl|3.03|  3.11|              9.6|        70|    5400|      38|         43| 6295|             755.4|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+------------------+
# only showing top 20 rows

# %% [markdown]
# # 🔵 5. withColumnRenamed()
#
# Rename a column.

# %%
df2 = df_csv.withColumnRenamed("price", "car_price")

# %% [markdown]
# # 🔵 6. drop()
#
# Remove one or more columns.

# %%
df2.drop("price").show()
# Out:
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+---------+
# |symboling|normalized-losses|       make|fuel-type|aspiration|num-of-doors| body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|car_price|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+---------+
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|    13495|
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|    16500|
# |        1|                ?|alfa-romero|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 171.2| 65.5|  52.4|       2823|       ohcv|             six|        152|       mpfi|2.68|  3.47|              9.0|       154|    5000|      19|         26|    16500|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|    13950|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         4wd|          front|      99.4| 176.6| 66.4|  54.3|       2824|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.0|       115|    5500|      18|         22|    17450|
# |        2|                ?|       audi|      gas|       std|         two|      sedan|         fwd|          front|      99.8| 177.3| 66.3|  53.1|       2507|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|    15250|
# |        1|              158|       audi|      gas|       std|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2844|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|    17710|
# |        1|                ?|       audi|      gas|       std|        four|      wagon|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2954|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|    18920|
# |        1|              158|       audi|      gas|     turbo|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.9|       3086|        ohc|            five|        131|       mpfi|3.13|   3.4|              8.3|       140|    5500|      17|         20|    23875|
# |        0|                ?|       audi|      gas|     turbo|         two|  hatchback|         4wd|          front|      99.5| 178.2| 67.9|  52.0|       3053|        ohc|            five|        131|       mpfi|3.13|   3.4|              7.0|       160|    5500|      16|         22|        ?|
# |        2|              192|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|    16430|
# |        0|              192|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|    16925|
# |        0|              188|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2710|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|    20970|
# |        0|              188|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2765|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|    21105|
# |        1|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3055|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      20|         25|    24565|
# |        0|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3230|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|    30760|
# |        0|                ?|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     103.5| 193.8| 67.9|  53.7|       3380|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|    41315|
# |        0|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     110.0| 197.0| 70.9|  56.3|       3505|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      15|         20|    36880|
# |        2|              121|  chevrolet|      gas|       std|         two|  hatchback|         fwd|          front|      88.4| 141.1| 60.3|  53.2|       1488|          l|           three|         61|       2bbl|2.91|  3.03|              9.5|        48|    5100|      47|         53|     5151|
# |        1|               98|  chevrolet|      gas|       std|         two|  hatchback|         fwd|          front|      94.5| 155.9| 63.6|  52.0|       1874|        ohc|            four|         90|       2bbl|3.03|  3.11|              9.6|        70|    5400|      38|         43|     6295|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+---------+
# only showing top 20 rows

# %% [markdown]
# # 🔵 7. dropDuplicates() / distinct()
#
# Remove duplicate rows.

# %%
df_csv.distinct().show()
# Out:
# +---------+-----------------+----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |symboling|normalized-losses|      make|fuel-type|aspiration|num-of-doors| body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|price|
# +---------+-----------------+----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |        0|              161|    peugot|      gas|       std|        four|      sedan|         rwd|          front|     107.9| 186.7| 68.4|  56.7|       3075|          l|            four|        120|       mpfi|3.46|  2.19|              8.4|        95|    5000|      19|         24|15580|
# |        2|                ?|   renault|      gas|       std|         two|  hatchback|         fwd|          front|      96.1| 176.8| 66.6|  50.5|       2460|        ohc|            four|        132|       mpfi|3.46|   3.9|              8.7|         ?|       ?|      23|         31| 9895|
# |        2|               83|    subaru|      gas|       std|         two|  hatchback|         fwd|          front|      93.7| 156.9| 63.4|  53.7|       2050|       ohcf|            four|         97|       2bbl|3.62|  2.36|              9.0|        69|    4900|      31|         36| 5118|
# |        0|               91|    toyota|      gas|       std|        four|      sedan|         fwd|          front|      95.7| 166.3| 64.4|  53.0|       2094|        ohc|            four|         98|       2bbl|3.19|  3.03|              9.0|        70|    4800|      38|         47| 7738|
# |        2|              161|mitsubishi|      gas|       std|         two|  hatchback|         fwd|          front|      93.7| 157.3| 64.4|  50.8|       1918|        ohc|            four|         92|       2bbl|2.97|  3.23|              9.4|        68|    5500|      37|         41| 5389|
# |        3|              197|    toyota|      gas|       std|         two|  hatchback|         rwd|          front|     102.9| 183.5| 67.7|  52.0|       3016|       dohc|             six|        171|       mpfi|3.27|  3.35|              9.3|       161|    5200|      19|         24|15998|
# |       -1|               95|     volvo|      gas|     turbo|        four|      sedan|         rwd|          front|     109.1| 188.8| 68.8|  55.5|       3049|        ohc|            four|        141|       mpfi|3.78|  3.15|              8.7|       160|    5300|      19|         25|19045|
# |        0|                ?|     mazda|   diesel|       std|           ?|      sedan|         fwd|          front|      98.8| 177.8| 66.5|  55.5|       2443|        ohc|            four|        122|        idi|3.39|  3.39|             22.7|        64|    4650|      36|         42|10795|
# |        1|              231|    nissan|      gas|       std|         two|  hatchback|         rwd|          front|      99.2| 178.5| 67.9|  49.7|       3139|       ohcv|             six|        181|       mpfi|3.43|  3.27|              9.0|       160|    5200|      19|         25|18399|
# |        0|               91|    toyota|      gas|       std|        four|      sedan|         fwd|          front|      95.7| 166.3| 64.4|  52.8|       2140|        ohc|            four|         98|       2bbl|3.19|  3.03|              9.0|        70|    4800|      28|         34| 9258|
# |       -1|                ?|    toyota|      gas|       std|        four|      wagon|         rwd|          front|     104.5| 187.8| 66.5|  54.1|       3151|       dohc|             six|        161|       mpfi|3.27|  3.35|              9.2|       156|    5200|      19|         24|15750|
# |        3|                ?|mitsubishi|      gas|     turbo|         two|  hatchback|         fwd|          front|      95.9| 173.2| 66.3|  50.2|       2926|        ohc|            four|        156|       spdi|3.59|  3.86|              7.0|       145|    5000|      19|         24|14489|
# |        0|               91|    toyota|      gas|       std|        four|      sedan|         fwd|          front|      95.7| 166.3| 64.4|  53.0|       2081|        ohc|            four|         98|       2bbl|3.19|  3.03|              9.0|        70|    4800|      30|         37| 6938|
# |        0|                ?|     isuzu|      gas|       std|        four|      sedan|         rwd|          front|      94.3| 170.7| 61.8|  53.5|       2337|        ohc|            four|        111|       2bbl|3.31|  3.23|              8.5|        78|    4800|      24|         29| 6785|
# |        1|              104|     mazda|      gas|       std|         two|  hatchback|         fwd|          front|      93.1| 159.1| 64.2|  54.1|       1900|        ohc|            four|         91|       2bbl|3.03|  3.15|              9.0|        68|    5000|      31|         38| 6095|
# |        1|              104|     mazda|      gas|       std|         two|  hatchback|         fwd|          front|      93.1| 159.1| 64.2|  54.1|       1905|        ohc|            four|         91|       2bbl|3.03|  3.15|              9.0|        68|    5000|      31|         38| 6795|
# |        3|              150|      saab|      gas|       std|         two|  hatchback|         fwd|          front|      99.1| 186.6| 66.5|  56.1|       2658|        ohc|            four|        121|       mpfi|3.54|  3.07|             9.31|       110|    5250|      21|         28|11850|
# |        0|                ?|     mazda|   diesel|       std|        four|      sedan|         rwd|          front|     104.9| 175.0| 66.1|  54.4|       2700|        ohc|            four|        134|        idi|3.43|  3.64|             22.0|        72|    4200|      31|         39|18344|
# |        3|              197|    toyota|      gas|       std|         two|  hatchback|         rwd|          front|     102.9| 183.5| 67.7|  52.0|       2976|       dohc|             six|        171|       mpfi|3.27|  3.35|              9.3|       161|    5200|      20|         24|16558|
# |        3|                ?|   porsche|      gas|       std|         two|convertible|         rwd|           rear|      89.5| 168.9| 65.0|  51.6|       2800|       ohcf|             six|        194|       mpfi|3.74|   2.9|              9.5|       207|    5900|      17|         25|37028|
# +---------+-----------------+----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# only showing top 20 rows

# %%
df_new=df_csv.dropDuplicates(["make"])

# %%
df_new.select("make","num-of-doors", "horsepower","price",).show()
# Out:
# +-------------+------------+----------+-----+
# |         make|num-of-doors|horsepower|price|
# +-------------+------------+----------+-----+
# |  alfa-romero|         two|       111|13495|
# |         audi|        four|       102|13950|
# |          bmw|         two|       101|16430|
# |    chevrolet|         two|        48| 5151|
# |        dodge|         two|        68| 5572|
# |        honda|         two|        58| 6479|
# |        isuzu|        four|        78| 6785|
# |       jaguar|        four|       176|32250|
# |        mazda|         two|        68| 5195|
# |mercedes-benz|        four|       123|25552|
# |      mercury|         two|       175|16503|
# |   mitsubishi|         two|        68| 5389|
# |       nissan|         two|        69| 5499|
# |       peugot|        four|        97|11900|
# |     plymouth|         two|        68| 5572|
# |      porsche|         two|       143|22018|
# |      renault|        four|         ?| 9295|
# |         saab|         two|       110|11850|
# |       subaru|         two|        69| 5118|
# |       toyota|         two|        62| 5348|
# +-------------+------------+----------+-----+
# only showing top 20 rows

# %% [markdown]
# # 🔵 8. orderBy() / sort()
#
# Sort rows.

# %%
df_new.orderBy("price").select("make","num-of-doors", "horsepower","price").show()
# Out:
# +-------------+------------+----------+-----+
# |         make|num-of-doors|horsepower|price|
# +-------------+------------+----------+-----+
# |         saab|         two|       110|11850|
# |       peugot|        four|        97|11900|
# |        volvo|        four|       114|12940|
# |  alfa-romero|         two|       111|13495|
# |         audi|        four|       102|13950|
# |          bmw|         two|       101|16430|
# |      mercury|         two|       175|16503|
# |      porsche|         two|       143|22018|
# |mercedes-benz|        four|       123|25552|
# |       jaguar|        four|       176|32250|
# |       subaru|         two|        69| 5118|
# |    chevrolet|         two|        48| 5151|
# |        mazda|         two|        68| 5195|
# |       toyota|         two|        62| 5348|
# |   mitsubishi|         two|        68| 5389|
# |       nissan|         two|        69| 5499|
# |        dodge|         two|        68| 5572|
# |     plymouth|         two|        68| 5572|
# |        honda|         two|        58| 6479|
# |        isuzu|        four|        78| 6785|
# +-------------+------------+----------+-----+
# only showing top 20 rows

# %%
df_new.orderBy(df_new.price.desc()).show()
# Out:
# +---------+-----------------+-------------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |symboling|normalized-losses|         make|fuel-type|aspiration|num-of-doors| body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|price|
# +---------+-----------------+-------------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |        0|                ?|      renault|      gas|       std|        four|      wagon|         fwd|          front|      96.1| 181.5| 66.5|  55.2|       2579|        ohc|            four|        132|       mpfi|3.46|   3.9|              8.7|         ?|       ?|      23|         31| 9295|
# |        2|              122|   volkswagen|   diesel|       std|         two|      sedan|         fwd|          front|      97.3| 171.7| 65.5|  55.7|       2261|        ohc|            four|         97|        idi|3.01|   3.4|             23.0|        52|    4800|      37|         46| 7775|
# |        0|                ?|        isuzu|      gas|       std|        four|      sedan|         rwd|          front|      94.3| 170.7| 61.8|  53.5|       2337|        ohc|            four|        111|       2bbl|3.31|  3.23|              8.5|        78|    4800|      24|         29| 6785|
# |        2|              137|        honda|      gas|       std|         two|  hatchback|         fwd|          front|      86.6| 144.6| 63.9|  50.8|       1713|        ohc|            four|         92|       1bbl|2.91|  3.41|              9.6|        58|    4800|      49|         54| 6479|
# |        1|              118|        dodge|      gas|       std|         two|  hatchback|         fwd|          front|      93.7| 157.3| 63.8|  50.8|       1876|        ohc|            four|         90|       2bbl|2.97|  3.23|             9.41|        68|    5500|      37|         41| 5572|
# |        1|              119|     plymouth|      gas|       std|         two|  hatchback|         fwd|          front|      93.7| 157.3| 63.8|  50.8|       1918|        ohc|            four|         90|       2bbl|2.97|  3.23|              9.4|        68|    5500|      37|         41| 5572|
# |        1|              128|       nissan|      gas|       std|         two|      sedan|         fwd|          front|      94.5| 165.3| 63.8|  54.5|       1889|        ohc|            four|         97|       2bbl|3.15|  3.29|              9.4|        69|    5200|      31|         37| 5499|
# |        2|              161|   mitsubishi|      gas|       std|         two|  hatchback|         fwd|          front|      93.7| 157.3| 64.4|  50.8|       1918|        ohc|            four|         92|       2bbl|2.97|  3.23|              9.4|        68|    5500|      37|         41| 5389|
# |        1|               87|       toyota|      gas|       std|         two|  hatchback|         fwd|          front|      95.7| 158.7| 63.6|  54.5|       1985|        ohc|            four|         92|       2bbl|3.05|  3.03|              9.0|        62|    4800|      35|         39| 5348|
# |        1|              104|        mazda|      gas|       std|         two|  hatchback|         fwd|          front|      93.1| 159.1| 64.2|  54.1|       1890|        ohc|            four|         91|       2bbl|3.03|  3.15|              9.0|        68|    5000|      30|         31| 5195|
# |        2|              121|    chevrolet|      gas|       std|         two|  hatchback|         fwd|          front|      88.4| 141.1| 60.3|  53.2|       1488|          l|           three|         61|       2bbl|2.91|  3.03|              9.5|        48|    5100|      47|         53| 5151|
# |        2|               83|       subaru|      gas|       std|         two|  hatchback|         fwd|          front|      93.7| 156.9| 63.4|  53.7|       2050|       ohcf|            four|         97|       2bbl|3.62|  2.36|              9.0|        69|    4900|      31|         36| 5118|
# |        0|              145|       jaguar|      gas|       std|        four|      sedan|         rwd|          front|     113.0| 199.6| 69.6|  52.8|       4066|       dohc|             six|        258|       mpfi|3.63|  4.17|              8.1|       176|    4750|      15|         19|32250|
# |       -1|               93|mercedes-benz|   diesel|     turbo|        four|      sedan|         rwd|          front|     110.0| 190.9| 70.3|  56.5|       3515|        ohc|            five|        183|        idi|3.58|  3.64|             21.5|       123|    4350|      22|         25|25552|
# |        3|              186|      porsche|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 168.9| 68.3|  50.2|       2778|        ohc|            four|        151|       mpfi|3.94|  3.11|              9.5|       143|    5500|      19|         27|22018|
# |        1|                ?|      mercury|      gas|     turbo|         two|  hatchback|         rwd|          front|     102.7| 178.4| 68.0|  54.8|       2910|        ohc|            four|        140|       mpfi|3.78|  3.12|              8.0|       175|    5000|      19|         24|16503|
# |        2|              192|          bmw|      gas|       std|         two|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|16430|
# |        2|              164|         audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|
# |        3|                ?|  alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|13495|
# |       -2|              103|        volvo|      gas|       std|        four|      sedan|         rwd|          front|     104.3| 188.8| 67.2|  56.2|       2912|        ohc|            four|        141|       mpfi|3.78|  3.15|              9.5|       114|    5400|      23|         28|12940|
# +---------+-----------------+-------------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# only showing top 20 rows

# %% [markdown]
# # 🔵 9. groupBy()
#
# Group rows by column(s).

# %%
df_csv.groupBy("make").count().show()
# Out:
# +-------------+-----+
# |         make|count|
# +-------------+-----+
# |       peugot|   11|
# |       jaguar|    3|
# |   mitsubishi|   13|
# |       toyota|   32|
# |         saab|    6|
# |     plymouth|    7|
# |         audi|    7|
# |  alfa-romero|    3|
# |          bmw|    8|
# |        dodge|    9|
# |        mazda|   17|
# |mercedes-benz|    8|
# |        isuzu|    4|
# |      porsche|    5|
# |    chevrolet|    3|
# |        honda|   13|
# |   volkswagen|   12|
# |      mercury|    1|
# |      renault|    2|
# |       nissan|   18|
# +-------------+-----+
# only showing top 20 rows

# %% [markdown]
# # 🔵 10. agg()
#
# Perform aggregations.

# %%
from pyspark.sql import functions as F

df_csv.agg(F.avg("price"), F.max("price")).show()
# Out:
# +------------------+----------+
# |        avg(price)|max(price)|
# +------------------+----------+
# |13207.129353233831|         ?|
# +------------------+----------+

# %% [markdown]
# # 🔵 11. join()
#
# Join two DataFrames.

# %%
df_csv.join(df2, df_csv.make == df2.make, "inner").show()
# Out:
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+---------+
# |symboling|normalized-losses|       make|fuel-type|aspiration|num-of-doors| body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|price|symboling|normalized-losses|       make|fuel-type|aspiration|num-of-doors| body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|car_price|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+---------+
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|13495|        1|                ?|alfa-romero|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 171.2| 65.5|  52.4|       2823|       ohcv|             six|        152|       mpfi|2.68|  3.47|              9.0|       154|    5000|      19|         26|    16500|
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|13495|        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|    16500|
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|13495|        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|    13495|
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|16500|        1|                ?|alfa-romero|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 171.2| 65.5|  52.4|       2823|       ohcv|             six|        152|       mpfi|2.68|  3.47|              9.0|       154|    5000|      19|         26|    16500|
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|16500|        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|    16500|
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|16500|        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|    13495|
# |        1|                ?|alfa-romero|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 171.2| 65.5|  52.4|       2823|       ohcv|             six|        152|       mpfi|2.68|  3.47|              9.0|       154|    5000|      19|         26|16500|        1|                ?|alfa-romero|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 171.2| 65.5|  52.4|       2823|       ohcv|             six|        152|       mpfi|2.68|  3.47|              9.0|       154|    5000|      19|         26|    16500|
# |        1|                ?|alfa-romero|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 171.2| 65.5|  52.4|       2823|       ohcv|             six|        152|       mpfi|2.68|  3.47|              9.0|       154|    5000|      19|         26|16500|        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|    16500|
# |        1|                ?|alfa-romero|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 171.2| 65.5|  52.4|       2823|       ohcv|             six|        152|       mpfi|2.68|  3.47|              9.0|       154|    5000|      19|         26|16500|        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|    13495|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|        0|                ?|       audi|      gas|     turbo|         two|  hatchback|         4wd|          front|      99.5| 178.2| 67.9|  52.0|       3053|        ohc|            five|        131|       mpfi|3.13|   3.4|              7.0|       160|    5500|      16|         22|        ?|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|        1|              158|       audi|      gas|     turbo|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.9|       3086|        ohc|            five|        131|       mpfi|3.13|   3.4|              8.3|       140|    5500|      17|         20|    23875|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|        1|                ?|       audi|      gas|       std|        four|      wagon|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2954|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|    18920|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|        1|              158|       audi|      gas|       std|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2844|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|    17710|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|        2|                ?|       audi|      gas|       std|         two|      sedan|         fwd|          front|      99.8| 177.3| 66.3|  53.1|       2507|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|    15250|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|        2|              164|       audi|      gas|       std|        four|      sedan|         4wd|          front|      99.4| 176.6| 66.4|  54.3|       2824|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.0|       115|    5500|      18|         22|    17450|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|    13950|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         4wd|          front|      99.4| 176.6| 66.4|  54.3|       2824|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.0|       115|    5500|      18|         22|17450|        0|                ?|       audi|      gas|     turbo|         two|  hatchback|         4wd|          front|      99.5| 178.2| 67.9|  52.0|       3053|        ohc|            five|        131|       mpfi|3.13|   3.4|              7.0|       160|    5500|      16|         22|        ?|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         4wd|          front|      99.4| 176.6| 66.4|  54.3|       2824|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.0|       115|    5500|      18|         22|17450|        1|              158|       audi|      gas|     turbo|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.9|       3086|        ohc|            five|        131|       mpfi|3.13|   3.4|              8.3|       140|    5500|      17|         20|    23875|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         4wd|          front|      99.4| 176.6| 66.4|  54.3|       2824|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.0|       115|    5500|      18|         22|17450|        1|                ?|       audi|      gas|       std|        four|      wagon|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2954|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|    18920|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         4wd|          front|      99.4| 176.6| 66.4|  54.3|       2824|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.0|       115|    5500|      18|         22|17450|        1|              158|       audi|      gas|       std|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2844|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|    17710|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+---------+
# only showing top 20 rows

# %% [markdown]
# # 🔵 12. union()
#
# Combine DataFrames vertically.

# %%
df3 = df_csv.union(df2)

# %% [markdown]
# # 🔵 13. unionByName()
#
# Union matching columns by name

# %%
df_csv.unionByName(df2).show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df_csv.unionByName(df2).show()
#
# File C:\Spark\python\pyspark\sql\dataframe.py:4043, in DataFrame.unionByName(self, other, allowMissingColumns)
#    3965 def unionByName(self, other: "DataFrame", allowMissingColumns: bool = False) -> "DataFrame":
#    3966     """Returns a new :class:`DataFrame` containing union of rows in this and another
#    3967     :class:`DataFrame`.
#    3968
#    (...)   4041     +----+----+----+----+----+----+
#    4042     """
# -> 4043     return DataFrame(self._jdf.unionByName(other._jdf, allowMissingColumns), self.sparkSession)
#
# File C:\Spark\python\lib\py4j-0.10.9.7-src.zip\py4j\java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File C:\Spark\python\pyspark\errors\exceptions\captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: Cannot resolve column name "price" among (symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, car_price).

# %% [markdown]
# # 🔵 14. limit()
#
# Limit the number of rows.

# %%
df_csv.limit(5).show()
# Out:
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |symboling|normalized-losses|       make|fuel-type|aspiration|num-of-doors| body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|price|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|13495|
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|16500|
# |        1|                ?|alfa-romero|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 171.2| 65.5|  52.4|       2823|       ohcv|             six|        152|       mpfi|2.68|  3.47|              9.0|       154|    5000|      19|         26|16500|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         4wd|          front|      99.4| 176.6| 66.4|  54.3|       2824|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.0|       115|    5500|      18|         22|17450|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+

# %% [markdown]
# # 🔵 15. sample()
#
# Get random sample.

# %%
df_csv.sample(withReplacement=False, fraction=0.3).show()
# Out:
# +---------+-----------------+-------------+---------+----------+------------+----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |symboling|normalized-losses|         make|fuel-type|aspiration|num-of-doors|body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|price|
# +---------+-----------------+-------------+---------+----------+------------+----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |        2|                ?|         audi|      gas|       std|         two|     sedan|         fwd|          front|      99.8| 177.3| 66.3|  53.1|       2507|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|15250|
# |        1|              158|         audi|      gas|       std|        four|     sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2844|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|17710|
# |        2|              192|          bmw|      gas|       std|         two|     sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|16430|
# |        0|              188|          bmw|      gas|       std|         two|     sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2710|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|20970|
# |        0|              188|          bmw|      gas|       std|        four|     sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2765|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|21105|
# |        0|                ?|          bmw|      gas|       std|         two|     sedan|         rwd|          front|     103.5| 193.8| 67.9|  53.7|       3380|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|41315|
# |        1|               98|    chevrolet|      gas|       std|         two| hatchback|         fwd|          front|      94.5| 155.9| 63.6|  52.0|       1874|        ohc|            four|         90|       2bbl|3.03|  3.11|              9.6|        70|    5400|      38|         43| 6295|
# |        1|              118|        dodge|      gas|       std|         two| hatchback|         fwd|          front|      93.7| 157.3| 63.8|  50.8|       1876|        ohc|            four|         90|       2bbl|2.97|  3.23|              9.4|        68|    5500|      31|         38| 6377|
# |        1|              148|        dodge|      gas|       std|        four|     sedan|         fwd|          front|      93.7| 157.3| 63.8|  50.6|       1989|        ohc|            four|         90|       2bbl|2.97|  3.23|              9.4|        68|    5500|      31|         38| 6692|
# |        1|              148|        dodge|      gas|     turbo|           ?|     sedan|         fwd|          front|      93.7| 157.3| 63.8|  50.6|       2191|        ohc|            four|         98|       mpfi|3.03|  3.39|              7.6|       102|    5500|      24|         30| 8558|
# |        1|              101|        honda|      gas|       std|         two| hatchback|         fwd|          front|      93.7| 150.0| 64.0|  52.6|       1837|        ohc|            four|         79|       1bbl|2.91|  3.07|             10.1|        60|    5500|      38|         42| 5399|
# |        0|              110|        honda|      gas|       std|        four|     sedan|         fwd|          front|      96.5| 163.4| 64.0|  54.5|       2010|        ohc|            four|         92|       1bbl|2.91|  3.41|              9.2|        76|    6000|      30|         34| 7295|
# |        0|               78|        honda|      gas|       std|        four|     wagon|         fwd|          front|      96.5| 157.1| 63.9|  58.3|       2024|        ohc|            four|         92|       1bbl|2.92|  3.41|              9.2|        76|    6000|      30|         34| 7295|
# |        1|              107|        honda|      gas|       std|         two|     sedan|         fwd|          front|      96.5| 169.1| 66.0|  51.0|       2293|        ohc|            four|        110|       2bbl|3.15|  3.58|              9.1|       100|    5500|      25|         31|10345|
# |        1|              113|        mazda|      gas|       std|        four|     sedan|         fwd|          front|      93.1| 166.8| 64.2|  54.1|       1945|        ohc|            four|         91|       2bbl|3.03|  3.15|              9.0|        68|    5000|      31|         38| 6695|
# |        3|              150|        mazda|      gas|       std|         two| hatchback|         rwd|          front|      95.3| 169.0| 65.7|  49.6|       2385|      rotor|             two|         70|       4bbl|   ?|     ?|              9.4|       101|    6000|      17|         23|13645|
# |        0|              115|        mazda|      gas|       std|        four|     sedan|         fwd|          front|      98.8| 177.8| 66.5|  55.5|       2410|        ohc|            four|        122|       2bbl|3.39|  3.39|              8.6|        84|    4800|      26|         32| 8495|
# |        0|              115|        mazda|      gas|       std|        four|     sedan|         fwd|          front|      98.8| 177.8| 66.5|  55.5|       2410|        ohc|            four|        122|       2bbl|3.39|  3.39|              8.6|        84|    4800|      26|         32|10245|
# |        0|              115|        mazda|      gas|       std|        four| hatchback|         fwd|          front|      98.8| 177.8| 66.5|  55.5|       2425|        ohc|            four|        122|       2bbl|3.39|  3.39|              8.6|        84|    4800|      26|         32|11245|
# |       -1|               93|mercedes-benz|   diesel|     turbo|        four|     sedan|         rwd|          front|     110.0| 190.9| 70.3|  56.5|       3515|        ohc|            five|        183|        idi|3.58|  3.64|             21.5|       123|    4350|      22|         25|25552|
# +---------+-----------------+-------------+---------+----------+------------+----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# only showing top 20 rows

# %% [markdown]
# # 🔵 16. dropna()
#
# Remove rows with null values.

# %%
df_csv.dropna().show()
df_csv.dropna(subset=["price"]).show()
# Out:
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |symboling|normalized-losses|       make|fuel-type|aspiration|num-of-doors| body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|price|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|13495|
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|16500|
# |        1|                ?|alfa-romero|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 171.2| 65.5|  52.4|       2823|       ohcv|             six|        152|       mpfi|2.68|  3.47|              9.0|       154|    5000|      19|         26|16500|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         4wd|          front|      99.4| 176.6| 66.4|  54.3|       2824|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.0|       115|    5500|      18|         22|17450|
# |        2|                ?|       audi|      gas|       std|         two|      sedan|         fwd|          front|      99.8| 177.3| 66.3|  53.1|       2507|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|15250|
# |        1|              158|       audi|      gas|       std|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2844|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|17710|
# |        1|                ?|       audi|      gas|       std|        four|      wagon|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2954|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|18920|
# |        1|              158|       audi|      gas|     turbo|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.9|       3086|        ohc|            five|        131|       mpfi|3.13|   3.4|              8.3|       140|    5500|      17|         20|23875|
# |        0|                ?|       audi|      gas|     turbo|         two|  hatchback|         4wd|          front|      99.5| 178.2| 67.9|  52.0|       3053|        ohc|            five|        131|       mpfi|3.13|   3.4|              7.0|       160|    5500|      16|         22|    ?|
# |        2|              192|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|16430|
# |        0|              192|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|16925|
# |        0|              188|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2710|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|20970|
# |        0|              188|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2765|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|21105|
# |        1|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3055|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      20|         25|24565|
# |        0|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3230|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|30760|
# |        0|                ?|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     103.5| 193.8| 67.9|  53.7|       3380|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|41315|
# |        0|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     110.0| 197.0| 70.9|  56.3|       3505|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      15|         20|36880|
# |        2|              121|  chevrolet|      gas|       std|         two|  hatchback|         fwd|          front|      88.4| 141.1| 60.3|  53.2|       1488|          l|           three|         61|       2bbl|2.91|  3.03|              9.5|        48|    5100|      47|         53| 5151|
# |        1|               98|  chevrolet|      gas|       std|         two|  hatchback|         fwd|          front|      94.5| 155.9| 63.6|  52.0|       1874|        ohc|            four|         90|       2bbl|3.03|  3.11|              9.6|        70|    5400|      38|         43| 6295|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# only showing top 20 rows
#
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |symboling|normalized-losses|       make|fuel-type|aspiration|num-of-doors| body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|price|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|13495|
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|16500|
# |        1|                ?|alfa-romero|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 171.2| 65.5|  52.4|       2823|       ohcv|             six|        152|       mpfi|2.68|  3.47|              9.0|       154|    5000|      19|         26|16500|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         4wd|          front|      99.4| 176.6| 66.4|  54.3|       2824|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.0|       115|    5500|      18|         22|17450|
# |        2|                ?|       audi|      gas|       std|         two|      sedan|         fwd|          front|      99.8| 177.3| 66.3|  53.1|       2507|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|15250|
# |        1|              158|       audi|      gas|       std|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2844|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|17710|
# |        1|                ?|       audi|      gas|       std|        four|      wagon|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2954|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|18920|
# |        1|              158|       audi|      gas|     turbo|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.9|       3086|        ohc|            five|        131|       mpfi|3.13|   3.4|              8.3|       140|    5500|      17|         20|23875|
# |        0|                ?|       audi|      gas|     turbo|         two|  hatchback|         4wd|          front|      99.5| 178.2| 67.9|  52.0|       3053|        ohc|            five|        131|       mpfi|3.13|   3.4|              7.0|       160|    5500|      16|         22|    ?|
# |        2|              192|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|16430|
# |        0|              192|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|16925|
# |        0|              188|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2710|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|20970|
# |        0|              188|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2765|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|21105|
# |        1|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3055|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      20|         25|24565|
# |        0|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3230|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|30760|
# |        0|                ?|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     103.5| 193.8| 67.9|  53.7|       3380|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|41315|
# |        0|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     110.0| 197.0| 70.9|  56.3|       3505|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      15|         20|36880|
# |        2|              121|  chevrolet|      gas|       std|         two|  hatchback|         fwd|          front|      88.4| 141.1| 60.3|  53.2|       1488|          l|           three|         61|       2bbl|2.91|  3.03|              9.5|        48|    5100|      47|         53| 5151|
# |        1|               98|  chevrolet|      gas|       std|         two|  hatchback|         fwd|          front|      94.5| 155.9| 63.6|  52.0|       1874|        ohc|            four|         90|       2bbl|3.03|  3.11|              9.6|        70|    5400|      38|         43| 6295|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# only showing top 20 rows

# %% [markdown]
# # 🔵 17. fillna()
#
# Replace null values.

# %%
df_csv.fillna({"price": 0}).show()
# Out:
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |symboling|normalized-losses|       make|fuel-type|aspiration|num-of-doors| body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|price|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|13495|
# |        3|                ?|alfa-romero|      gas|       std|         two|convertible|         rwd|          front|      88.6| 168.8| 64.1|  48.8|       2548|       dohc|            four|        130|       mpfi|3.47|  2.68|              9.0|       111|    5000|      21|         27|16500|
# |        1|                ?|alfa-romero|      gas|       std|         two|  hatchback|         rwd|          front|      94.5| 171.2| 65.5|  52.4|       2823|       ohcv|             six|        152|       mpfi|2.68|  3.47|              9.0|       154|    5000|      19|         26|16500|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         fwd|          front|      99.8| 176.6| 66.2|  54.3|       2337|        ohc|            four|        109|       mpfi|3.19|   3.4|             10.0|       102|    5500|      24|         30|13950|
# |        2|              164|       audi|      gas|       std|        four|      sedan|         4wd|          front|      99.4| 176.6| 66.4|  54.3|       2824|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.0|       115|    5500|      18|         22|17450|
# |        2|                ?|       audi|      gas|       std|         two|      sedan|         fwd|          front|      99.8| 177.3| 66.3|  53.1|       2507|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|15250|
# |        1|              158|       audi|      gas|       std|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2844|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|17710|
# |        1|                ?|       audi|      gas|       std|        four|      wagon|         fwd|          front|     105.8| 192.7| 71.4|  55.7|       2954|        ohc|            five|        136|       mpfi|3.19|   3.4|              8.5|       110|    5500|      19|         25|18920|
# |        1|              158|       audi|      gas|     turbo|        four|      sedan|         fwd|          front|     105.8| 192.7| 71.4|  55.9|       3086|        ohc|            five|        131|       mpfi|3.13|   3.4|              8.3|       140|    5500|      17|         20|23875|
# |        0|                ?|       audi|      gas|     turbo|         two|  hatchback|         4wd|          front|      99.5| 178.2| 67.9|  52.0|       3053|        ohc|            five|        131|       mpfi|3.13|   3.4|              7.0|       160|    5500|      16|         22|    ?|
# |        2|              192|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|16430|
# |        0|              192|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2395|        ohc|            four|        108|       mpfi| 3.5|   2.8|              8.8|       101|    5800|      23|         29|16925|
# |        0|              188|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2710|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|20970|
# |        0|              188|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     101.2| 176.8| 64.8|  54.3|       2765|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      21|         28|21105|
# |        1|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3055|        ohc|             six|        164|       mpfi|3.31|  3.19|              9.0|       121|    4250|      20|         25|24565|
# |        0|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     103.5| 189.0| 66.9|  55.7|       3230|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|30760|
# |        0|                ?|        bmw|      gas|       std|         two|      sedan|         rwd|          front|     103.5| 193.8| 67.9|  53.7|       3380|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      16|         22|41315|
# |        0|                ?|        bmw|      gas|       std|        four|      sedan|         rwd|          front|     110.0| 197.0| 70.9|  56.3|       3505|        ohc|             six|        209|       mpfi|3.62|  3.39|              8.0|       182|    5400|      15|         20|36880|
# |        2|              121|  chevrolet|      gas|       std|         two|  hatchback|         fwd|          front|      88.4| 141.1| 60.3|  53.2|       1488|          l|           three|         61|       2bbl|2.91|  3.03|              9.5|        48|    5100|      47|         53| 5151|
# |        1|               98|  chevrolet|      gas|       std|         two|  hatchback|         fwd|          front|      94.5| 155.9| 63.6|  52.0|       1874|        ohc|            four|         90|       2bbl|3.03|  3.11|              9.6|        70|    5400|      38|         43| 6295|
# +---------+-----------------+-----------+---------+----------+------------+-----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# only showing top 20 rows

# %% [markdown]
# # 🔵 18. replace()
#
# Replace specific values.

# %%
df_rep=df_csv.replace({"jaguar": "TATA-jaguar"}, subset=["make"])

# %%
df_rep.select("make","num-of-doors", "horsepower","price",).distinct().show(700)
# Out:
# +-------------+------------+----------+-----+
# |         make|num-of-doors|horsepower|price|
# +-------------+------------+----------+-----+
# |        mazda|         two|       101|13645|
# |       subaru|        four|        94| 9960|
# |       toyota|         two|       161|16558|
# |       peugot|        four|        95|15580|
# |     plymouth|        four|        68| 7609|
# |mercedes-benz|        four|       155|34184|
# |          bmw|        four|       182|30760|
# |          bmw|         two|       182|41315|
# |       nissan|         two|        69| 6649|
# |        mazda|         two|       135|15645|
# |     plymouth|         two|       102| 7957|
# |       subaru|        four|       111|11694|
# |         audi|        four|       115|17450|
# |   volkswagen|         two|        90|11595|
# |mercedes-benz|        four|       123|25552|
# |       toyota|         two|       112| 9538|
# |   volkswagen|        four|        85| 8495|
# |        mazda|        four|       120|18280|
# |       peugot|        four|        95|17075|
# |      porsche|         two|       288|    ?|
# |       subaru|         two|        73| 7603|
# |        isuzu|        four|        70|    ?|
# |       nissan|        four|        69| 7999|
# |     plymouth|        four|        68| 6692|
# |       toyota|        four|        56| 7898|
# |   volkswagen|        four|        52| 7995|
# |mercedes-benz|         two|       155|35056|
# |   mitsubishi|        four|        88| 6989|
# |        dodge|        four|        68| 6692|
# |mercedes-benz|        four|       123|31600|
# |       toyota|        four|        62| 8778|
# |         audi|        four|       102|13950|
# |       nissan|        four|        69| 7349|
# |      renault|         two|         ?| 9895|
# |       subaru|        four|        82| 8013|
# |         audi|        four|       110|17710|
# |         audi|        four|       110|18920|
# |        volvo|        four|       114|16845|
# |   mitsubishi|         two|        68| 6669|
# |       peugot|        four|        95|13860|
# |  alfa-romero|         two|       154|16500|
# |        dodge|           ?|       102| 8558|
# |        volvo|        four|       114|13415|
# |        volvo|        four|       162|18420|
# |       nissan|         two|        69| 8249|
# |         saab|         two|       160|18150|
# |   mitsubishi|         two|        88| 8499|
# |     plymouth|        four|        68| 6229|
# |       toyota|        four|        70| 9258|
# |        dodge|        four|        68| 7609|
# |       toyota|        four|       156|15690|
# |         saab|        four|       110|15510|
# |        dodge|         two|        68| 6377|
# |        honda|        four|        76| 7295|
# |       toyota|        four|        92| 9988|
# |   mitsubishi|         two|       145|12629|
# |       peugot|        four|        95|13200|
# |       subaru|        four|        82| 7126|
# |       toyota|        four|        70| 7738|
# |        isuzu|         two|        70|    ?|
# |       nissan|         two|        69| 7299|
# |       toyota|        four|        92| 8948|
# |     plymouth|         two|       145|12764|
# |       subaru|         two|        69| 5118|
# |       toyota|         two|       116| 8449|
# |   volkswagen|        four|        68| 9495|
# |        honda|         two|        60| 5399|
# |   mitsubishi|         two|       145|14869|
# |          bmw|        four|       121|24565|
# |   volkswagen|         two|        52| 7775|
# |         saab|        four|       110|12170|
# |        mazda|        four|        72|18344|
# |       subaru|        four|        94|10198|
# |   volkswagen|         two|        85| 7975|
# |        honda|        four|       101|12945|
# |        mazda|         two|       101|10945|
# |        volvo|        four|       114|22625|
# |       subaru|        four|        82| 7775|
# |mercedes-benz|         two|       184|45400|
# |       toyota|         two|        62| 5348|
# |        isuzu|         two|        90|11048|
# |        mazda|         two|        68| 6095|
# |       toyota|         two|        62| 6338|
# |       toyota|         two|        70| 8238|
# |       subaru|         two|        73| 7053|
# |       toyota|        four|       156|15750|
# |        honda|         two|       100|10345|
# |       nissan|        four|       152|13499|
# |   volkswagen|        four|        68|13845|
# |       toyota|        four|        62| 6488|
# |       peugot|        four|        97|12440|
# |       subaru|        four|        82| 7463|
# |          bmw|        four|       121|21105|
# |        dodge|         two|       145|12964|
# |   volkswagen|        four|       100| 9995|
# |        mazda|         two|        68| 6795|
# |       nissan|        four|        69| 7499|
# |        volvo|        four|       114|12940|
# |        mazda|        four|        84|10245|
# |       peugot|        four|        95|16900|
# |  TATA-jaguar|        four|       176|32250|
# |       nissan|        four|       152|14399|
# |        dodge|        four|        68| 6229|
# |mercedes-benz|         two|       123|28176|
# |mercedes-benz|        four|       184|40960|
# |  TATA-jaguar|         two|       262|36000|
# |       toyota|        four|        92|11248|
# |      porsche|         two|       207|34028|
# |       toyota|        four|        62| 7898|
# |        mazda|        four|        68| 6695|
# |       nissan|         two|       160|17199|
# |        volvo|        four|       114|15985|
# |       nissan|         two|        55| 7099|
# |  TATA-jaguar|        four|       176|35550|
# |       toyota|         two|       116|11549|
# |         audi|         two|       160|    ?|
# |        mazda|        four|        84|11245|
# |       subaru|        four|        82| 9233|
# |        isuzu|        four|        78| 6785|
# |          bmw|         two|       101|16430|
# |        honda|         two|        58| 6479|
# |        mazda|         two|        68| 5195|
# |   mitsubishi|        four|        88| 8189|
# |      renault|        four|         ?| 9295|
# |       toyota|         two|       116| 9639|
# |      mercury|         two|       175|16503|
# |   mitsubishi|         two|        68| 6189|
# |       nissan|         two|       200|19699|
# |        mazda|         two|        84| 8845|
# |       toyota|        four|        70| 6938|
# |        honda|        four|        86|10295|
# |       toyota|        four|        92|10898|
# |        honda|        four|        86| 8845|
# |        mazda|           ?|        64|10795|
# |       subaru|        four|       111|11259|
# |       toyota|         two|       116|17669|
# |        mazda|         two|        84|10595|
# |   mitsubishi|         two|       145|14489|
# |        honda|         two|        86| 9095|
# |       nissan|        four|        97| 9549|
# |       peugot|        four|        97|16630|
# |         saab|        four|       160|18620|
# |   volkswagen|         two|        90| 9980|
# |         audi|         two|       110|15250|
# |      porsche|         two|       207|32528|
# |         saab|         two|       110|11850|
# |    chevrolet|         two|        48| 5151|
# |       toyota|        four|        73|10698|
# |       peugot|        four|        95|16695|
# |         saab|         two|       110|15040|
# |       nissan|         two|        69| 5499|
# |       nissan|         two|       160|18399|
# |       toyota|        four|        56| 7788|
# |       toyota|         two|        70| 8058|
# |       toyota|         two|       112| 9298|
# |    chevrolet|        four|        70| 6575|
# |        mazda|         two|       101|11845|
# |        dodge|         two|       102| 7957|
# |      porsche|         two|       143|22018|
# |       toyota|        four|        62| 6918|
# |mercedes-benz|        four|       123|28248|
# |   mitsubishi|        four|       116| 9279|
# |  alfa-romero|         two|       111|13495|
# |          bmw|        four|       101|16925|
# |    chevrolet|         two|        70| 6295|
# |        volvo|        four|       114|16515|
# |       peugot|        four|        97|11900|
# |        dodge|        four|        88| 8921|
# |       nissan|         two|        69| 7799|
# |        volvo|        four|       134|21485|
# |         audi|        four|       140|23875|
# |        mazda|        four|        84| 8495|
# |       nissan|        four|        69| 6849|
# |   volkswagen|        four|        88|12290|
# |        honda|         two|        86| 7895|
# |        volvo|        four|       162|18950|
# |          bmw|         two|       121|20970|
# |     plymouth|        four|        88| 8921|
# |        volvo|        four|       160|19045|
# |        honda|         two|        76| 6855|
# |   mitsubishi|         two|        68| 5389|
# |      porsche|         two|       207|37028|
# |       toyota|         two|       116|11199|
# |  alfa-romero|         two|       111|16500|
# |       toyota|        four|        70| 8358|
# |   volkswagen|        four|       110|13295|
# |       toyota|        four|        70| 7198|
# |        mazda|        four|        68| 7395|
# |       peugot|        four|       142|18150|
# |   mitsubishi|         two|       102| 7689|
# |       toyota|         two|       116| 9989|
# |        honda|         two|        76| 7129|
# |          bmw|        four|       182|36880|
# |        volvo|        four|       106|22470|
# |       toyota|         two|       161|15998|
# |   mitsubishi|         two|       116| 9959|
# |       peugot|        four|        95|17950|
# |     plymouth|         two|        68| 5572|
# |        honda|         two|        76| 6529|
# |   volkswagen|        four|        85| 8195|
# |        dodge|         two|        68| 5572|
# |       nissan|        four|        97| 8949|
# +-------------+------------+----------+-----+

# %% [markdown]
# # 🔵 19. cast()
#
# Change data type.

# %%
df2 = df_csv.withColumn("price", df_csv.price.cast("int"))

# %% [markdown]
# # 🔵 20. pivot()
#
# Convert rows to columns.

# %%
df_csv.groupBy("make").pivot("fuel-type").sum("horsepower").show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df_csv.groupBy("make").pivot("fuel-type").sum("horsepower").show()
#
# File C:\Spark\python\pyspark\sql\group.py:49, in df_varargs_api.<locals>._api(self, *cols)
#      47 def _api(self: "GroupedData", *cols: str) -> DataFrame:
#      48     name = f.__name__
# ---> 49     jdf = getattr(self._jgd, name)(_to_seq(self.session._sc, cols))
#      50     return DataFrame(jdf, self.session)
#
# File C:\Spark\python\lib\py4j-0.10.9.7-src.zip\py4j\java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File C:\Spark\python\pyspark\errors\exceptions\captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: "horsepower" is not a numeric column. Aggregation function can only be applied on a numeric column.

# %% [markdown]
# # 🔵 21. explode()
#
# Flatten array column.

# %%
from pyspark.sql.functions import explode

df2 = df.withColumn("skill", explode(df.skills))
df2.show()
