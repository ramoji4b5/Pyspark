# %%
import findspark
findspark.init()
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("RDD VS DataFrame").getOrCreate()

# %%
sc = spark.sparkContext

# %% [markdown]
# ## RDD vs Data Frame

# %% [markdown]
# # RDD Version (Low-level approach)

# %%
data = [("John", 2000), ("Mary", 3000)]

rdd = sc.parallelize(data)

result = rdd.map(lambda x: (x[0], x[1] * 10))
print(result.collect())
# Out:
# [('John', 20000), ('Mary', 30000)]

# %% [markdown]
# # DataFrame Version (High-level & optimized)

# %%
df = spark.createDataFrame(data, ["name", "salary"])

df2 = df.withColumn("salary", df.salary * 10)
df2.show()
# Out:
# +----+------+
# |name|salary|
# +----+------+
# |John| 20000|
# |Mary| 30000|
# +----+------+

# %% [markdown]
# # Filtering Operation

# %%
nums = sc.parallelize([1,2,3,4,5,6])
evens = nums.filter(lambda x: x % 2 == 0)
print(evens.collect())
# Out:
# [2, 4, 6]

# %%
df = spark.createDataFrame([(1,), (2,), (3,), (4,), (5,), (6,)], ["num"])
df.filter(df.num % 2 == 0).show()
# Out:
# +---+
# |num|
# +---+
# |  2|
# |  4|
# |  6|
# +---+

# %% [markdown]
# # Word Count (RDD vs DataFrame)

# %%
rdd = sc.textFile("README.md")

result = (
    rdd.flatMap(lambda x: x.split(" "))
       .map(lambda x: (x, 1))
       .reduceByKey(lambda a, b: a + b)
)

print(result.collect())
# Out:
# [('#', 3), ('SQL', 2), ('query', 1), ('from', 1), ('excel', 1), ('&amp;', 1), ('##', 1), ('', 40), ('Streamlit-based', 1), ('for', 2), ('using', 1), ('natural', 1), ('language', 1), ('and', 1), ('LLMs.', 1), ('---', 2), ('###', 5), ('✅', 1), ('Prerequisites', 1), ('-', 3), ('Python', 1), ('`pip`', 1), ('`conda`', 1), ('management', 1), ('Recommended:', 1), ('use', 1), ('environment', 1), ('(`venv`', 1), ('`conda`)', 1), ('🛠️', 1), ('1.', 1), ('**Clone', 1), ('https://github.com/ramoji4b5/GenAI_Usecase_OpenAI', 1), ('python', 1), ('-m', 1), ('venv', 1), ('Mac/Linux', 1), ('.venv\\Scripts\\activate', 1), ('```', 6), ('bash', 1), ('pip', 1), ('install', 1), ('requirements.txt', 1), ('Run', 1), ('streamlit', 1), ('base', 1), ('URL', 1), ('Breakdown:', 1), ('postgres:', 1), ('admin:', 1), ('localhost:', 1), ('host', 1), ('IP', 1), ('domain)', 1), ('name', 1), ('GenAI_Usecase_OpenAI', 1), ('database', 3), ('🚀', 1), ('Getting', 1), ('Started', 1), ('This', 1), ('project', 1), ('is', 1), ('a', 2), ('application', 1), ('querying', 1), ('data', 1), ('3.8+', 1), ('or', 3), ('package', 1), ('virtual', 1), ('Installation', 1), ('the', 2), ('repo**', 1), ('```bash', 2), ('git', 1), ('clone', 1), ('cd', 1), ('sql_chatbot', 1), ('.venv', 1), ('source', 1), ('.venv/bin/activate', 1), ('Windows', 1), ('Install', 1), ('dependencies', 1), ('-r', 1), ('▶️', 1), ('App', 1), ('run', 1), ('sql_chatbot/app.py', 1), ('Data', 1), ('connections', 1), ('string', 1), ('format', 1), ('postgresql+psycopg2://username:password@host:port/database_name', 1), ('your', 3), ('PostgreSQL', 3), ('username', 1), ('password', 1), ('(can', 1), ('be', 1), ('5432:', 1), ('default', 1), ('port', 1), ('hr_data:', 1)]

# %%
from pyspark.sql.functions import explode, split

df = spark.read.text("README.md")

df2 = df.select(explode(split(df.value, " ")).alias("word")) \
        .groupBy("word") \
        .count()

df2.show(100)
# Out:
# +--------------------+-----+
# |                word|count|
# +--------------------+-----+
# |                port|    1|
# |    requirements.txt|    1|
# |          management|    1|
# |             ```bash|    2|
# |                Data|    1|
# |                  -r|    1|
# |            password|    1|
# |             (`venv`|    1|
# |                name|    1|
# |https://github.co...|    1|
# |                   ✅|    1|
# |              format|    1|
# |               using|    1|
# |             **Clone|    1|
# |                  -m|    1|
# |                 for|    2|
# |                (can|    1|
# |            `conda`)|    1|
# |                 URL|    1|
# |               query|    1|
# |          localhost:|    1|
# |           postgres:|    1|
# |               excel|    1|
# |                  be|    1|
# |               .venv|    1|
# |            database|    3|
# |              admin:|    1|
# |          PostgreSQL|    3|
# |                your|    3|
# |             package|    1|
# |  sql_chatbot/app.py|    1|
# |         sql_chatbot|    1|
# |  .venv/bin/activate|    1|
# |                  cd|    1|
# |              source|    1|
# |             project|    1|
# |             natural|    1|
# |       Prerequisites|    1|
# |                  is|    1|
# |             Getting|    1|
# |           Mac/Linux|    1|
# |               clone|    1|
# |                bash|    1|
# |                3.8+|    1|
# |        Installation|    1|
# |              string|    1|
# |postgresql+psycop...|    1|
# |                 use|    1|
# |               LLMs.|    1|
# |                 ---|    2|
# |                data|    1|
# |                 Run|    1|
# |                   -|    3|
# |          Breakdown:|    1|
# |                host|    1|
# |                  🚀|    1|
# |         connections|    1|
# |                  ▶️|    1|
# |                venv|    1|
# |                 the|    2|
# |            language|    1|
# |             virtual|    1|
# |                 🛠️|    1|
# |                from|    1|
# |                 App|    1|
# |               `pip`|    1|
# |              repo**|    1|
# |             Started|    1|
# |                 and|    1|
# |                 SQL|    2|
# |        Recommended:|    1|
# |     Streamlit-based|    1|
# |.venv\Scripts\act...|    1|
# |                 pip|    1|
# |             domain)|    1|
# |                 ```|    6|
# |                   #|    3|
# |                 ###|    5|
# |              Python|    1|
# |             install|    1|
# |               &amp;|    1|
# |                  IP|    1|
# |                  ##|    1|
# |                This|    1|
# |                 run|    1|
# |                 git|    1|
# |         application|    1|
# |             `conda`|    1|
# |                   a|    2|
# |                    |   40|
# |           streamlit|    1|
# |                base|    1|
# |                  1.|    1|
# |         environment|    1|
# |             default|    1|
# |            username|    1|
# |            querying|    1|
# |                  or|    3|
# |             Install|    1|
# |               5432:|    1|
# +--------------------+-----+
# only showing top 100 rows
